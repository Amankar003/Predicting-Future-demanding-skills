# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('freelancer_earnings_bd.csv')

# %%
data
# Out:
#       Freelancer_ID       Job_Category       Platform Experience_Level  \
# 0                 1    Web Development         Fiverr         Beginner
# 1                 2    App Development         Fiverr         Beginner
# 2                 3    Web Development         Fiverr         Beginner
# 3                 4         Data Entry  PeoplePerHour     Intermediate
# 4                 5  Digital Marketing         Upwork           Expert
# ...             ...                ...            ...              ...
# 1945           1946     Graphic Design         Fiverr         Beginner
# 1946           1947                SEO         Upwork     Intermediate
# 1947           1948                SEO  PeoplePerHour           Expert
# 1948           1949                SEO     Freelancer     Intermediate
# 1949           1950     Graphic Design     Freelancer           Expert
#
#      Client_Region  Payment_Method  Job_Completed  Earnings_USD  Hourly_Rate  \
# ...

# %%
data.shape
# Out:
# (1950, 15)

# %%
data.describe()
# Out:
#        Freelancer_ID  Job_Completed  Earnings_USD  Hourly_Rate  \
# count    1950.000000    1950.000000   1950.000000  1950.000000
# mean      975.500000     150.864103   5017.566667    52.579774
# std       563.060832      85.480770   2926.279918    26.927584
# min         1.000000       5.000000     51.000000     5.020000
# 25%       488.250000      76.000000   2419.000000    30.047500
# 50%       975.500000     149.000000   5048.000000    52.285000
# 75%      1462.750000     225.000000   7608.250000    75.125000
# max      1950.000000     299.000000   9991.000000    99.830000
#
#        Job_Success_Rate  Client_Rating  Job_Duration_Days  Rehire_Rate  \
# count       1950.000000    1950.000000        1950.000000  1950.000000
# mean          74.951846       3.995892          44.704615    44.556913
# std           14.615735       0.575976          26.022998    20.193842
# min           50.160000       3.000000           1.000000    10.000000
# ...

# %%
data.isnull().count()
# Out:
# Freelancer_ID        1950
# Job_Category         1950
# Platform             1950
# Experience_Level     1950
# Client_Region        1950
# Payment_Method       1950
# Job_Completed        1950
# Earnings_USD         1950
# Hourly_Rate          1950
# Job_Success_Rate     1950
# Client_Rating        1950
# Job_Duration_Days    1950
# Project_Type         1950
# Rehire_Rate          1950
# Marketing_Spend      1950
# dtype: int64

# %%
data['Job_Category'].unique()
# Out:
# array([7, 0, 3, 4, 2, 1, 5, 6], dtype=int64)

# %%
data['Job_Category'].value_counts()
# Out:
# 5    265
# 7    256
# 0    248
# 2    244
# 3    238
# 6    237
# 4    231
# 1    231
# Name: Job_Category, dtype: int64

# %%
Job_Category_count = data['Job_Category'].value_counts()

# %%
Job_Category_count
# Out:
# 5    265
# 7    256
# 0    248
# 2    244
# 3    238
# 6    237
# 4    231
# 1    231
# Name: Job_Category, dtype: int64

# %%
Platform_count = data['Platform'].value_counts()

# %%
Platform_count
# Out:
# 4    420
# 3    395
# 0    391
# 1    386
# 2    358
# Name: Platform, dtype: int64

# %%
Client_Region_count = data['Client_Region'].value_counts()

# %%
Client_Region_count
# Out:
# Australia      298
# USA            292
# Middle East    291
# Asia           281
# UK             280
# Europe         262
# Canada         246
# Name: Client_Region, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 8))
plt.pie(Job_Category_count, labels=Job_Category_count.index, autopct="%1.1f%%", colors=plt.cm.Paired.colors)
plt.title("Job Category Distribution", fontsize=14)
plt.show()

# %%
plt.figure(figsize = (8,8))
plt.pie(Platform_count, labels=Platform_count.index, autopct="%1.1f%%", colors=plt.cm.Paired.colors)
plt.title("Platform Count", fontsize = 14)
plt.show()

# %%
plt.figure(figsize = (8,8))
plt.pie(Client_Region_count, labels=Client_Region_count.index, autopct="%1.1f%%", colors=plt.cm.Paired.colors)
plt.title("Client Region Count", fontsize = 14)
plt.show()

# %% [markdown]
# Encoding Categorocal Values

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoders = {}
for col in ["Job_Category", "Experience_Level", "Platform"]:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col])
    label_encoders[col] = le

# %%
label_encoders
# Out:
# {'Job_Category': LabelEncoder(),
#  'Experience_Level': LabelEncoder(),
#  'Platform': LabelEncoder()}

# %%
le = LabelEncoder()
encoded_values = le.fit_transform(Job_Category)

print("Original Categories : ", Job_Category)
print("Encoded Values : ", encoded_values)

print("Label Mapping:", dict(zip(le.classes_, range(len(le.classes_)))))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 2
#       1 le = LabelEncoder()
# ----> 2 encoded_values = le.fit_transform(Job_Category)
#       4 print("Original Categories : ", Job_Category)
#       5 print("Encoded Values : ", encoded_values)
#
# NameError: name 'Job_Category' is not defined

# %%
from sklearn.preprocessing import LabelEncoder

# Sample categorical data
categories = ['apple', 'banana', 'orange', 'apple', 'orange', 'banana', 'banana']

# Initialize and fit LabelEncoder
le = LabelEncoder()
encoded_values = le.fit_transform(categories)

# Display encoded values
print("Original Categories:", categories)
print("Encoded Values:", encoded_values)

# Display the mapping of labels
print("Label Mapping:", dict(zip(le.classes_, range(len(le.classes_)))))

# %% [markdown]
# Prepare input and output variables

# %%
features = ["Job_Category", "Experience_Level", "Platform", "Job_Success_Rate"]
target = "Earnings_USD"

# %%
x = data[features]
y = data[target]

# %%
# Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 42)

# %%
x_train
# Out:
#       Job_Category  Experience_Level  Platform  Job_Success_Rate
# 1863             1                 0         2             77.25
# 1235             6                 2         4             68.43
# 1849             3                 2         4             82.29
# 1189             1                 0         3             85.41
# 572              4                 0         4             69.83
# ...            ...               ...       ...               ...
# 1130             5                 2         3             86.17
# 1294             7                 0         1             90.03
# 860              2                 1         4             88.78
# 1459             3                 2         3             82.94
# 1126             7                 0         3             54.35
#
# [1462 rows x 4 columns]

# %%
y_train
# Out:
# 1863    1486
# 1235    4913
# 1849    9962
# 1189    2254
# 572     6565
#         ...
# 1130    7711
# 1294    4937
# 860     5342
# 1459    2866
# 1126    9377
# Name: Earnings_USD, Length: 1462, dtype: int64

# %%
x_test
# Out:
#       Job_Category  Experience_Level  Platform  Job_Success_Rate
# 1614             6                 0         2             66.65
# 1405             7                 2         1             73.73
# 974              2                 1         4             51.56
# 1055             1                 1         4             67.54
# 307              2                 1         2             66.15
# ...            ...               ...       ...               ...
# 1307             7                 2         3             90.09
# 334              5                 1         4             52.30
# 869              6                 2         4             97.31
# 1421             7                 1         0             75.36
# 1601             0                 0         4             66.17
#
# [488 rows x 4 columns]

# %%
y_test
# Out:
# 1614    4263
# 1405    9534
# 974     5579
# 1055    9835
# 307     2398
#         ...
# 1307    2960
# 334       92
# 869     1439
# 1421    4561
# 1601    1208
# Name: Earnings_USD, Length: 488, dtype: int64

# %%
# Making Regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Make Predictions

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([4673.41573021, 4941.40587704, 4949.04896479, 5095.61915083,
#        5001.31854352, 5101.19272607, 4987.65061829, 4768.9689379 ,
#        5113.67805269, 5053.28249364, 5095.76903602, 5033.2354705 ,
#        4863.26214027, 4771.49509421, 4937.33713277, 5196.64179451,
#        5393.00742387, 4808.99994018, 5087.44432199, 5055.40286521,
#        4874.13037706, 4821.35384763, 5489.59376169, 5065.26030455,
#        5280.52097662, 5237.29999391, 5123.95435984, 5023.39345548,
#        4582.21215444, 5020.97338195, 4640.67881896, 4685.09032079,
#        4964.40874875, 4938.5022965 , 4551.35314798, 5218.5927911 ,
#        4997.2181689 , 5163.62230062, 5161.918438  , 5278.89586742,
#        5286.78060981, 5299.7084152 , 4948.26791696, 5177.24725547,
#        4899.1927185 , 4961.17154639, 5174.73342091, 4780.16570099,
#        4917.82301117, 4995.99837829, 4990.98940334, 5222.00275735,
#        4979.35687075, 4973.80870033, 4841.51988832, 5294.89647896,
# ...

# %%
# Evaluate Model Performance

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 2525.341786002722

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 8494124.829438133

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 2914.4681898140752

# %%
r2 = r2_score(y_test, y_pred)
r2
# Out:
# -0.00010262062210086853

# %%
from sklearn.metrics import accuracy_score

# %%
threshold = y.median()
y_pred_class = (y_pred >= threshold).astype(int)
y_test_class = (y_test >= threshold).astype(int)
accuracy = accuracy_score(y_test_class, y_pred_class)

# %%
accuracy
# Out:
# 0.5286885245901639

# %%
# Making a predictive System

# %%
"Job_Category", "Experience_Level", "Platform", "Job_Success_Rate"
